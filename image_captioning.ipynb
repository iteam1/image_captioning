# %% [markdown]
# ### image captioning
#
# This notebook base on [nttuan8 blog](https://nttuan8.com/).
#
# We build model to convert content in the image to text, this is called `image_captioning`, follow this processing: `image` -> `text` -> `voice`
#
# **Usages**:
#
# - For helping elders who have weak eyes can understand what is going on around them.
#
# - search image follow the caption
#
# We can download the dataset [here](https://academictorrents.com/details/9dea07ba660a722ae1008c4c8afdd303b6f6e53b), they have `8000` samples.
#
# - `6000` for training set meaning `75%`
#
# - `1000` for validation set `12.5%`
#
# - `1000` for testing set `12.5%`
#
# Your `Flickr8k` download will contain 2 floder:
#
# - floder `Images`: contain the images
#
# - text file `captions`: contain the captions
#
# ![workflow](./imgs/image_captioning.png)

# %% [markdown]
# **Image embedding with Inception**
#
# ![inceptionV3](./imgs/inceptionV3.png)
#
# In this notebook we will using pre-trained model `Inception v3` with dataset `ImageNet` to get the `embedding vector`
#
# - The input shape `229x229x3` (we will resize the input)
# - The `embedding vector`: `256x1`

# %% [markdown]
# **Text processing**
# We will process the text input before give it to the `RNNs` model, Follow these steps:
# - *Step1*: convert text from uppercase to lowercase, ex: "Hello" -> "hello"
# - *Step2*: Remove the special character, ex: "@#$%^&"
# - *Step3*: Remove the text-num charater: ex "hey199"
# - *Step4*: we add `startseq` and `endseq` for notice the begin and ending of the caption, ex: "startseq a girl going to wooden building endseq"
#
# We need to check how many unique character in the `8000*5` captions, but we don't care about the charater just appear few time (Someone treat them like noise and useless) so we need to set a `accept_range` for each word's appearance
#
# We also check the longest caption (maybe 34 characters) and add `padding` to let caption's lenght equal, ex: " A", " A girl going", " A girl going into a wooden". So we got `total_character` =  `unique_charater` + `1 padding character`

# %% [markdown]
# **Word embedding**
#
# You have to convert text to number (this called: word embedding), there is 1 famous word embedding name `word2vec` published by Google
#
# - One hot encoding: This is a easiest way to convert text to vector have the lenght equal to the lenght of your dictionary, but if your diction is to large, may be > 10,000 words, that will be a big memory problem, and also the distance from similar words did not count.
#
# - Co-ocurrence matrix: In 1957 J.R.Firth said: "You can understand meaning of a word by the nearly words", `co-occurrence matrix` based on this idea. but there are some defect:
#     + when the dictionary size increase the `matrix_dimension` is increase too
#     + storage a `co-occurence matrix` need large memory
#     + there is so many zero value in the matrix
#     to descrease `co-ocurrence matrix` size, we use `SVD` (singular value decomposition), with `m` is the dimension of the `co-occurence matrix` and `n` is the dimension of matrix after `SVD` `n` < `m`?$ O(mn^{2})$, and it is hard to add new word inside your matrix
#
# - Word to vector (word2vec):
#     Mikolov said the meaning of the word and the the context is strong correlation
#     + `word2vec` trying to predict the nearly word, not counting them
#     It make the calculation is faster and easier to transfer learning when we add new word into the dictionary
#     `word2vec` trying to predict the words around in the radius `m`:
#     $$J_{{\theta}} = -\frac{1}{T} \prod_{i=1}^{T} \prod_{j=-m,j\neq0}^{m}p (w_{t+j}|w_t;\theta)$$
#
#     There are 2 architecture `CBoW`,`Skip-Gram`
#     + `CBoW`: need a context then it will predict the word, ex: "I ... you" -> Love
#     + `Skip-Gram`: given a text then we trying to predict a context (the rest of words), ex: Love -> "I ... you"
#
# ![cbow_skip-gram](./imgs/cbow_skip-gram.png)
#
#  pretrained model `GLoVe` [GloVe stanford](https://nlp.stanford.edu/projects/glove/) [GloVe Kaggle](https://www.kaggle.com/datasets/anindya2906/glove6b?select=glove.6B.200d.txt)

# %%
from google.colab import drive
drive.mount('./drive')
# Out:
# Mounted at ./drive

# %%
import os

# %%
os.listdir('/content/drive/MyDrive/Flickr8k')
# Out:
# ['captions.txt', 'Images']

# %%
# show how many image in Images floder
imgs = os.listdir('/content/drive/MyDrive/Flickr8k/Images')
print(f'so we have: {len(imgs)}')
print(f'meaning we have: {len(imgs)*5} caption')
# Out:
# so we have: 8091
# meaning we have: 40455 caption

# %%
import glob

# %%
# Check the number of images again with glob
imgs = glob.glob('/content/drive/MyDrive/Flickr8k/Images/' +'*.jpg')
print(f'actually we have: {len(imgs)} imgs')
# Out:
# actually we have: 8091 imgs

# %%
# read the caption file
def load_doc(filename):
    # open the file as read only
    file = open(filename,'r')
    # read all text
    text = file.read()
    # close file
    file.close()
    return text

captions = load_doc('/content/drive/MyDrive/Flickr8k/captions.txt')
print(f'captions: {type(captions)}')
print(f'captions lenght: {len(captions)}')
captions = captions.split('\n')
captions[:5]
# Out:
# captions: <class 'str'>
# captions lenght: 3319294
# ['image,caption',
#  '1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .',
#  '1000268201_693b08cb0e.jpg,A girl going into a wooden building .',
#  '1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .',
#  '1000268201_693b08cb0e.jpg,A little girl climbing the stairs to her playhouse .']

# %%
# remove the first element in the list
captions.pop(0)
print(f'captions: {type(captions)}')
print(f"captions lenght: {len(captions)}")
captions[:5]
# Out:
# captions: <class 'list'>
# captions lenght: 40456
# ['1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .',
#  '1000268201_693b08cb0e.jpg,A girl going into a wooden building .',
#  '1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .',
#  '1000268201_693b08cb0e.jpg,A little girl climbing the stairs to her playhouse .',
#  '1000268201_693b08cb0e.jpg,A little girl in a pink dress going into a wooden cabin .']

# %%
print(f'the last caption: {captions[-1]}')
captions.pop(-1)
print(f"captions'slenght: {len(captions)}")
# Out:
# the last caption:
# captions'slenght: 40455

# %%
# convert captions to this form id_image: [caption1,caption2,caption3,caption4,caption5]
# get all image name
imgs = []
for i in range(len(captions)):
    img = captions[i].split(',')
    img = img[0]
    imgs.append(img)
    
print(f'imgs lenght before set: {len(imgs)}')

# get the unique image name
imgs= set(imgs)
print(f'imgs lenght after set: {len(imgs)}')
# Out:
# imgs lenght before set: 40455
# imgs lenght after set: 8091

# %%
captions[0].split(",")
# Out:
# ['1000268201_693b08cb0e.jpg',
#  'A child in a pink dress is climbing up a set of stairs in an entry way .']

# %%
# create a dict with image name
img_dict = {}
for img in imgs:
    img_dict[img] = []

for img_cap in captions:
    img_cap = img_cap.split(',')
    img,cap = img_cap[0],img_cap[-1]
    img_dict[img].append(cap)

# %%
import random

# %%
# test our list
img = random.choice(list(imgs))
caps = img_dict[img]
print(f'img: {img}')
print(f'cap lenght: {len(caps)}')
print(caps)
# Out:
# img: 3597924257_d0da3c5fe6.jpg
# cap lenght: 5
# ['A brown and white dog runs in a field of yellow flowers .', 'A brown dog running at a lean across a lawn .', 'A brown dog runs through a field of grass spotted with yellow flowers', 'The brown dog runs through the field .', 'The tan and white dog is running in the field .']

# %%
import string

# %%
# prepare translation table for removing punctuation
table = str.maketrans('', '', string.punctuation)
table
# Out:
# {33: None,
#  34: None,
#  35: None,
#  36: None,
#  37: None,
#  38: None,
#  39: None,
#  40: None,
#  41: None,
#  42: None,
#  43: None,
#  44: None,
#  45: None,
#  46: None,
#  47: None,
#  58: None,
#  59: None,
#  60: None,
#  61: None,
#  62: None,
#  63: None,
#  64: None,
#  91: None,
#  92: None,
#  93: None,
#  94: None,
#  95: None,
#  96: None,
#  123: None,
#  124: None,
#  125: None,
#  126: None}

# %%
for img,cap_list in img_dict.items():
    # loop over each caption 
    for i,cap in enumerate(cap_list):
        # slpit the cap each word
        cap = cap.split()
        # convert to lower case
        cap = [word.lower() for word in cap]
        # remove punctuation from each token
        cap = [word.translate(table) for word in cap]
        # remove hanging 's' and 'a'
        cap = [word for word in cap if len(word) >1]
        # remove word with number 
        cap = [word for word in cap if word.isalpha()]
        # merge each word become a string again
        cap_list[i] = ' '.join(cap)

# %%
# test our list
img = random.choice(list(imgs))
caps = img_dict[img]
print(f'img: {img}')
print(f'cap lenght: {len(caps)}')
print(caps)
# Out:
# img: 1449625950_fc9a8d02d9.jpg
# cap lenght: 5
# ['brown dog and tan dog are playing in tall grass', 'there is white dog and chocolate colored dog running in the grass', 'two dogs are playing together in the grass', 'two dogs play in grassy field', 'two dogs running on grass']

# %%
# save your caption
def save_captions(captions,filename):
    lines = list()
    for img,cap_list in captions.items():
        for cap in cap_list:
            lines.append(img + ',' + cap)
        data = '\n'.join(lines)
        file =  open(filename,'w')
        file.write(data)
        file.close()

# we did make the clean_caps.txt      
save_captions(img_dict,'./clean_caps.txt')

# %%
docs = load_doc('/content/drive/MyDrive/clean_caps.txt')
for i,img in enumerate(imgs):
  print(img)
# Out:
# Streaming output truncated to the last 5000 lines.
# 3430526230_234b3550f6.jpg
# 3255620561_7644747791.jpg
# 2618322793_5fb164d86a.jpg
# 1234817607_924893f6e1.jpg
# 2899501488_90d5da5474.jpg
# 424869823_7aec015d87.jpg
# 317488612_70ac35493b.jpg
# 3242808166_8638150274.jpg
# 3038941104_17ee91fc03.jpg
# 1643915227_9f48068772.jpg
# 495116214_f1df479fb0.jpg
# 146098876_0d99d7fb98.jpg
# 3046431231_dc48851062.jpg
# 416788726_5b4eb1466e.jpg
# 3470129475_9e58b6742c.jpg
# 2471974379_a4a4d2b389.jpg
# 3486340101_ff01d8f3f9.jpg
# 3649224118_abe73c672c.jpg
# 497579819_f91b26f7d3.jpg
        imgs[i] = img
        img_dict[img] = []
    #print(img_dict)
    # get caption list    
    for line in doc.split('\n'):
        tokens = line.split(',')
        # get image name and caption (image,caption)
        img,cap= tokens[0],tokens[1:]
        if img in imgs:
            # add startseq and endseq
            cap = 'startseq ' + ' '.join(cap) + ' endseq'
            # store
            img_dict[img].append(cap)
    return img_dict

img_dict = load_captions('./clean_caps.txt','/content/drive/MyDrive/Flickr8k/Images/')

# %%
img_dict
# Out:
# {'374124237_51f62b6937.jpg': ['startseq girl dressed in black is posing for the camera endseq',
#   'startseq woman dressed in black endseq',
#   'startseq woman in black clothes with one leg up endseq',
#   'startseq woman in black leggings and beige cowboy boots endseq',
#   'startseq and some kicking boots endseq'],
#  '397982550_cf9f5cdb74.jpg': ['startseq bald man stands in snowy side street endseq',
#   'startseq bald man wearing jacket looks at icy sidewalk endseq',
#   'startseq man is standing on an icy street with building beside him endseq',
#   'startseq man wearing gray coat looks to the right on snowy street endseq',
#   'startseq man wearing grey jacket standing on the side of street endseq'],
#  '3736786640_70df13be2c.jpg': ['startseq two boys are playing on trampoline endseq',
#   'startseq two kids in black trunks bouncing on wet trampoline endseq',
#   'startseq two teenage boys in black swim trunks play on trampoline endseq',
#   'startseq two wet boys in swim trunks are sitting on trampoline endseq',
#   'startseq young laughing boys on wet vinyl mat endseq'],
#  '405970010_8cebaa77d3.jpg': ['startseq hiker on snowcovered mountain overlooking valley endseq',
#   'startseq man carrying backpack stands on snowy area endseq',
#   'startseq man in snow clothes and red helmet is on top of mountain with other mountains in the background endseq',
#   'startseq man wearing huge backpack and blue jacket with many distant mountains in the background endseq',
#   'startseq smiling hiker poses on top of snowcovered mountain endseq'],
#  '384465575_31294122c0.jpg': ['startseq man and woman are biking on sunny day endseq',
#   'startseq man and woman cyclists ride pass signs on rural road endseq',
#   'startseq two bicyclists ride down hill endseq',
#   'startseq two friends bike down hill endseq',
#   'startseq two people are riding their bicycles on dirt road endseq'],
#  '401079494_562454c4d6.jpg': ['startseq black and gray dog endseq',
#   'startseq two black dogs fight endseq',
#   'startseq two black poodles fighting endseq',
#   'startseq manicured lawn endseq',
#   'startseq two small black dogs facing each other with their mouths open endseq'],
#  '391579205_c8373b5411.jpg': ['startseq dog jumping up to touch woman hand endseq',
#   'startseq dog jumps to an elderly woman endseq',
#   'startseq an airborne dog on leash with woman endseq',
#   'startseq the small dog is leaping in the air toward the woman hand endseq',
#   'startseq the woman in the blue sweater encourages the dog to jump in the air endseq'],
#  '408233586_f2c1be3ce1.jpg': ['startseq brown and black dog fetching tennis ball in lake endseq',
#   'startseq dog in water with its head cocked to the side looking at ball endseq',
#   'startseq dog is running through the water chasing after ball endseq',
#   'startseq dog is shaking off water in lake as red and green tennis ball floats by endseq',
#   'startseq dog playing with ball in water endseq'],
#  '381514859_b40418d9c3.jpg': ['startseq two small white dogs are in yard chasing red ball endseq',
#   'startseq two small white dogs chasing after red ball endseq',
#   'startseq two small white dogs chasing red ball endseq',
#   'startseq two west highland terriers chase red ball endseq',
#   'startseq two white dogs chase after red ball in yard in front of white fence endseq'],
#  '405615014_03be7ef618.jpg': ['startseq man in lime green vest directs traffic endseq',
#   'startseq policeman wearing green vest blows his whistle and moves his arms endseq',
#   'startseq policeman wearing neon green vest has whistle in his mouth while directing traffic endseq',
#   'startseq police officer in yellow vest directs traffic endseq',
#   'startseq seattle police endseq'],
#  '404216567_75b50b5a36.jpg': ['startseq person in uniform is standing in front of toll bridge endseq',
#   'startseq woman in bright safety jacket is standing next to large pipes endseq',
#   'startseq woman wearing fluorecent safety jacket stands near equipment endseq',
#   'startseq woman wearing neon jacket standing next to large machine endseq',
#   'startseq the woman is wearing yellow jacket and blue pants endseq'],
#  '380590140_25b9889772.jpg': ['startseq busy highway scene with woman crossing crosswalk on the left endseq',
#   'startseq lady crosses busy road on the crosswalk endseq',
#   'startseq woman crosses street while traffic lines up in the opposite direction endseq',
#   'startseq two others at corner and one person sitting on ground endseq',
#   'startseq woman walking in crosswalk near busy street endseq'],
#  '386656845_4e77c3e3da.jpg': ['startseq black dog and brown dog are standing next to each other in the snow endseq',
#   'startseq little tan dog is in confrontation with large black dog in the snow endseq',
#   'startseq scruffy golden dog meeting black doberman in the snow endseq',
#   'startseq two dogs in the snow endseq',
#   'startseq two dogs standing in snow endseq'],
#  '3727752439_907795603b.jpg': ['startseq large woman puts her sunglasses on endseq',
#   'startseq woman in black dress holding sunglasses endseq',
#   'startseq woman wearing black and white outfit while holding her sunglasses endseq',
#   'startseq the lady is holding her glasses endseq',
#   'startseq the woman with blond hair holds her sunglasses endseq'],
#  '394161692_2576920777.jpg': ['startseq couple shopping for plants and flowers endseq',
#   'startseq man in brown jacket with his arm around person in black jacket at flower shop endseq',
#   'startseq people are waiting outside lawn and garden seller endseq',
#   'startseq the man has his arm around the woman in flower market endseq',
#   'startseq the man has his arm on the woman as they shop in an outdoor market endseq'],
#  '3739833689_a0038545bd.jpg': ['startseq little boy puts bat on his forehead and spins around endseq',
#   'startseq young boy holds his head to baseball bat on the green grass endseq',
#   'startseq young boy is spinning around baseball bat on the grass endseq',
#   'startseq little boy puts his forehead on the baseball bat and spins around to make himself dizzy endseq',
#   'startseq the little boy is wearing red shorts and white tshirt and has his head resting on baseball bat endseq'],
#  '405534893_2d0f3b0147.jpg': ['startseq man climbs mountain endseq',
#   'startseq man climbs the side of mountain endseq',
#   'startseq shirtless man climbs wall in nature endseq',
#   'startseq holds rope endseq',
#   'startseq two men climbing mountain endseq'],
#  '3727740053_3baa94ffcb.jpg': ['startseq one man kicks another in the shoulder at martial arts event endseq',
#   'startseq two martial artists compete in match endseq',
#   'startseq two men are participating in karate match endseq',
#   'startseq two men in an oriental fighting contest endseq',
#   'startseq two men in karate uniforms kicking each other endseq'],
#  '392467282_00bb22e201.jpg': ['startseq two big brown dogs running through the snow endseq',
#   'startseq two brown dogs are running over snow in line endseq',
#   'startseq two brown dogs walking through snow endseq',
#   'startseq two dogs running in the snow endseq',
#   'startseq two weimaraners running in the snow endseq'],
#  '3730457171_e66dde8c91.jpg': ['startseq little girl rides toy bike and laughs endseq',
#   'startseq little girl rides tricycle endseq',
#   'startseq little girl rides tricycle endseq',
#   'startseq young girl rides on toy bicycle with her mouth open endseq',
#   'startseq little girl riding her toy on the sidewalk endseq'],
#  '3744832122_2f4febdff6.jpg': ['startseq boy pitches in baseball game endseq',
#   'startseq boy winding up for pitch endseq',
#   'startseq young baseball player winds up to throw the ball endseq',
#   'startseq young person pitches in baseball game endseq',
#   'startseq the baseball player is throwing the ball endseq'],
#  '391723162_3bdeb7ea33.jpg': ['startseq black dog digging through the snow endseq',
#   'startseq black dog digs in the snow endseq',
#   'startseq large black dog is digging in the deep snow endseq',
#   'startseq small black and brown dog is standing in the snow endseq',
#   'startseq black dog digging in white snow endseq'],
#  '3726629271_7639634703.jpg': ['startseq four dogs are playing and jumping in the air outside endseq',
#   'startseq four dogs jumping in the air in field endseq',
#   'startseq one jumping to reach it endseq',
#   'startseq two of them leaping in the air endseq',
#   'startseq two dogs on hind legs and two seated dogs are looking at something in the air endseq'],
#  '380537190_11d6c0a412.jpg': ['startseq group of people stand at farmers market on dreary day endseq',
#   'startseq white tented fruit stand with several people shopping in it endseq',
#   'startseq people shop for fresh produce at an outdoor market in the city endseq',
#   'startseq people visiting street market endseq',
#   'startseq several people shop at an outdoor farmer market on cloudy day endseq'],
#  '404850242_3a55a4c874.jpg': ['startseq an asian lady in red jacket taking photo endseq',
#   'startseq an asian woman is taking photograph outside white columned building endseq',
#   'startseq an older dark haired woman is taking picture endseq',
#   'startseq woman in red coat takes picture near marble columns at twilight endseq',
#   'startseq woman wearing red coat begins to take picture endseq'],
#  '404702274_fa8b3fe378.jpg': ['startseq black and white dog is leaping from snowy path endseq',
#   'startseq brown and white dog jumps in the air to catch snowball endseq',
#   'startseq dog jumps up and tries to catch lump of snow endseq',
#   'startseq dog jumping to catch falling snow out in the woods endseq',
#   'startseq above snow covered ground endseq'],
#  '387830531_e89c192b92.jpg': ['startseq brown dog about to jump on smaller black and tan dog endseq',
#   'startseq large dog playing with smaller dog endseq',
#   'startseq two dogs are playing together outside endseq',
#   'startseq two dogs playing in the grass with an adult nearby endseq',
#   'startseq two dogs playing with each other endseq'],
#  '397815951_3b02090324.jpg': ['startseq dog mouth opens to expose its sharp teeth endseq',
#   'startseq dog tries to bite another dog endseq',
#   'startseq two black and white dogs fighting with each other endseq',
#   'startseq two dogs play on the wooden floor inside endseq',
#   'startseq two dogs play with each other on wood floor endseq'],
#  '3732728142_86364a706e.jpg': ['startseq baby in baby seat wearing red beanie that says love endseq',
#   'startseq baby in red hat sitting in stroller is holding doll endseq',
#   'startseq baby with red hat sits in his stroller endseq',
#   'startseq litttle baby plays with her teddy bear endseq',
#   'startseq baby wearing red hat in car seat endseq'],
#  '406901451_7eafd7568a.jpg': ['startseq black and brown dog attempts to catch red ball in its mouth endseq',
#   'startseq brown and black dog approaching red ball endseq',
#   'startseq brown and black dog is trying to catch red ball in its mouth endseq',
#   'startseq dog with mouth open to catch the red ball endseq',
#   'startseq tan and black dog opens its mouth for red ball endseq'],
#  '405534993_5158644f98.jpg': ['startseq rock climber endseq',
#   'startseq one is on the ground while the other climbs endseq',
#   'startseq two men climb large rock endseq',
#   'startseq two people rock climbing endseq',
#   'startseq two rock climbers scaling sheer cliff endseq'],
#  '3726170067_094cc1b7e5.jpg': ['startseq balding man with glasses stands in front of colorful display endseq',
#   'startseq bald man wearing glasses endseq',
#   'startseq man in brown coat in front of sign with tree endseq',
#   'startseq man wearing glasses and blazer stands in front of billboard sign endseq',
#   'startseq an older man is standing outside in front of truck endseq'],
#  '386470686_1ae9242878.jpg': ['startseq man crouched in the bare branches of fallen tree endseq',
#   'startseq man in white shirt and khaki pants crouches on fallen tree trunk endseq',
#   'startseq crouches on the trunk of tree endseq',
#   'startseq man is crouched on top of horizontal tree endseq',
#   'startseq man sitting in the middle of branches on fallen tree endseq'],
#  '3738685861_8dfff28760.jpg': ['startseq blond child is playing with metal yard ornament endseq',
#   'startseq child dressed in blue sits next to plants endseq',
#   'startseq child in blur shirt playing in flower bed endseq',
#   'startseq child plays outside by garden endseq',
#   'startseq small child is sitting playing with an adornment in small garden endseq'],
#  '383223174_7165a54c30.jpg': ['startseq brown dog plays with stick endseq',
#   'startseq brown dog wearing key is playing in the dirt endseq',
#   'startseq lean light brown dog has his head down on the ground playing with stick endseq',
#   'startseq tan dog rests his head in the sand endseq',
#   'startseq two dogs and person endseq'],
#  '399679638_d3036da331.jpg': ['startseq brown dog and gray dog are playing in the snow endseq',
#   'startseq dogs play in the snow endseq',
#   'startseq two dogs are wrestling on the ground in the snow endseq',
#   'startseq two dogs playing in the snow endseq',
#   'startseq two dogs play in the snow endseq'],
#  '393284934_d38e1cd6fe.jpg': ['startseq yawning endseq',
#   'startseq dog that is wearing red cap is standing by guitar with its mouth wide open endseq',
#   'startseq dog wearing hat stretches open its mouth endseq',
#   'startseq dog wearing red hat opens its mouth wide endseq',
#   'startseq and has its mouth wide open endseq'],
#  '3759230208_1c2a492b12.jpg': ['startseq boy at the end of slip and slide endseq',
#   'startseq boy is being splashed in the face whilst riding blue ring along yellow water slide endseq',
#   'startseq young boy slides down water slide with his eyes closed endseq',
#   'startseq young boy slides on slip slide endseq',
#   'startseq young boy splashes down water slide on lawn endseq'],
#  '405331006_4e94e07698.jpg': ['startseq man in blue cowboy hat is riding white horse endseq',
#   'startseq man in blue is riding horse on dirt road endseq',
#   'startseq man wearing blue hat and shirt is riding white horse endseq',
#   'startseq person in blue cowboy hat rides horse down dirt trail endseq',
#   'startseq the person in the blue shirt and blue hat is riding white horse endseq'],
#  '373219198_149af371d9.jpg': ['startseq dog standing in rocky area endseq',
#   'startseq small brown dog stands on driveway near wooden poles with his tongue sticking out endseq',
#   'startseq near posts in rural area endseq',
#   'startseq the golden dog is standing by logs in parking lot endseq',
#   'startseq the light brown dog is in an uncrowded parking lot endseq'],
#  '377872672_d499aae449.jpg': ['startseq four dogs play in the snow with the city skyline behind them endseq',
#   'startseq the dogs are playing in the snow endseq',
#   'startseq and one is wearing winter coat endseq',
#   'startseq three dogs playing in the snow while one dog wears jacket endseq',
#   'startseq with city in the background endseq'],
#  '392976422_c8d0514bc3.jpg': ['startseq boy in blue shirt is walking along tan and blue wall endseq',
#   'startseq boy in stripes walking along ledge endseq',
#   'startseq boy scales the wall endseq',
#   'startseq child in striped shirt is walking along wall endseq',
#   'startseq boy in striped tshirt walking along ledge endseq'],
#  '3730011219_588cdc7972.jpg': ['startseq man and young child walk along the beach shore endseq',
#   'startseq man and toddler are walking along the beach in front of the ocean endseq',
#   'startseq standing next to child endseq',
#   'startseq man with bucket and girl in hat on the beach endseq',
#   'startseq and walking with child next to the water endseq'],
#  '3728695560_00ec1ca492.jpg': ['startseq little girl looks at birthday cake while man holds baby endseq',
#   'startseq and child sit in front of birthday cake endseq',
#   'startseq man holding baby and an older child admire birthday cake with candles endseq',
#   'startseq man holding baby with girl and birthday cake endseq',
#   'startseq candles are lit on cake while man holds baby endseq'],
#  '374103842_17873ce505.jpg': ['startseq man dressed in black is smoking cigarette endseq',
#   'startseq man in black shirt and cast smokes cigarette endseq',
#   'startseq man in black shirt with cigarette in front of others endseq',
#   'startseq man in black smokes cigarette in basement endseq',
#   'startseq man stands near wall and smokes cigarette endseq'],
#  '3726730085_2468ee9220.jpg': ['startseq baby is lifted into the air by man wearing no shirt endseq',
#   'startseq child being held over the head of an adult endseq',
#   'startseq man and young child endseq',
#   'startseq man with no shirt holding baby aloft endseq',
#   'startseq man raising young boy into the clear blue sky endseq'],
#  '386655611_1329495f97.jpg': ['startseq black dog carries huge stick in its mouth endseq',
#   'startseq black dog is carrying huge stick whilst walking in the snow endseq',
#   'startseq snow covered stick endseq',
#   'startseq dog carries very large tree branch in the snow endseq',
#   'startseq the brown and white dog carries very large stick across the snow endseq'],
#  '393810324_1c33760a95.jpg': ['startseq large black dog and small brown dog are playing in the house endseq',
#   'startseq large black dog has his paw on small brown dog endseq',
#   'startseq large black dog relaxes while small brown dog investigates nearby doorway endseq',
#   'startseq two dogs play together endseq',
#   'startseq with french door and persian rug in the background endseq'],
#  '409327234_7b29eecb4e.jpg': ['startseq woman sits alone against brick wall endseq',
#   'startseq woman sits at restaurant with her back against brick wall endseq',
#   'startseq looking out window endseq',
#   'startseq woman sitting against brick wall inside building endseq',
#   'startseq the woman wearing blue shirt sits in front of brick wall endseq'],
#  '3745451546_fc8ec70cbd.jpg': ['startseq hiker ascends snowy hill endseq',
#   'startseq man reaches the top of tall sand dune endseq',
#   'startseq person is hiking to the top of hill endseq',
#   'startseq person walks up white sandy hill against the blue sky endseq',
#   'startseq the person is wearing shorts and climbing gray sand hill under blue sky endseq'],
#  '399212516_d68046b277.jpg': ['startseq military man says hello to group of children waving american flags endseq',
#   'startseq veteran in brown uniform at parade with children and american flags endseq',
#   'startseq military official greets children who are waving american flags endseq',
#   'startseq the man in the military uniform greets children waving american flags endseq',
#   'startseq young children waving american flags for soldier endseq'],
#  '378170167_9b5119d918.jpg': ['startseq white dog is running along path outside endseq',
#   'startseq white dog travels along narrow path in park setting endseq',
#   'startseq yellow dog running along forest path endseq',
#   'startseq the twotone dog is running down the trail endseq',
#   'startseq white dog traveling alone down paved path through some woods endseq'],
#  '398662202_97e5819b79.jpg': ['startseq one child reaches up for something while another stands beside him endseq',
#   'startseq one child with colourful toy and another child reaching up endseq',
#   'startseq two babies in sweaters playing with toy endseq',
#   'startseq two children have expressions of happiness as they reach for something out of sight endseq',
#   'startseq two kids playing on street endseq'],
#  '408748500_e8dc8c0c4f.jpg': ['startseq boy wears red coat endseq',
#   'startseq child in red coat stands near funny decoration endseq',
#   'startseq child wearing coat looks back at someone endseq',
#   'startseq the boy is dressed in red coat and stands next to statue endseq',
#   'startseq the girl in the red jacket is next to picture of funny face endseq'],
#  '387974450_bcd205daac.jpg': ['startseq black dog runs along field where black birds are beginning to fly endseq',
#   'startseq dark colored dog running in field with multilple birds in the background endseq',
#   'startseq dog runs at birds taking flight endseq',
#   'startseq river in the background endseq',
#   'startseq the dog chases the birds in the field endseq'],
#  '397286183_745abbf40d.jpg': ['startseq man in blue jacket widely opens his big blue eyes as man behind him closes his eyes as he covers his mouth endseq',
#   'startseq man wearing blue jacket looks at the camera endseq',
#   'startseq startled man wearing blue jacket is looking at the camera endseq',
#   'startseq wide eyed guy in blue jacket is holding beer and standing next to guy holding his nose endseq',
#   'startseq man in blue is posing for the camera endseq'],
#  '406642021_9ec852eccf.jpg': ['startseq climber wearing red shirt is climbing rock face on snowy day endseq',
#   'startseq man in red shirt climbing rock with his bare hands endseq',
#   'startseq man is climbing over short but sheer rocky cliff endseq',
#   'startseq mean wearing red shirt clinging to rock face endseq',
#   'startseq person scales rock endseq'],
#  '381239475_044cbffa2b.jpg': ['startseq black dog is swimming while carrying tennis endseq',
#   'startseq black dog swimming in the water with tennis ball in his mouth endseq',
#   'startseq black dog swims through the water with tennis ball in its mouth endseq',
#   'startseq dog swims in water with blue and green tennis ball in its mouth endseq',
#   'startseq dog with ball in its mouth swims in the water endseq'],
#  '395461421_c586b136de.jpg': ['startseq group of teenage boys on road jumping joyfully endseq',
#   'startseq four boys running and jumping endseq',
#   'startseq four kids jumping on the street with blue car in the back endseq',
#   'startseq four young men are running on street and jumping for joy endseq',
#   'startseq sveral young man jumping down the street endseq'],
#  '399246804_b4b5dc70e1.jpg': ['startseq black dachshund sniffs another dog wearing striped shirt endseq',
#   'startseq dog wearing striped sweater touches noses with another dog endseq',
#   'startseq white dog wearing zepra print shirt is nose to nose with black dog wearing pink collar endseq',
#   'startseq white dog with sweater on and black and brown dog touching noses endseq',
#   'startseq two dogs meeting nose to nose endseq'],
#  '380041023_0dfd712ef1.jpg': ['startseq brown and black dog runs through the leaves endseq',
#   'startseq brown dog is running endseq',
#   'startseq brown dog with red collar jumping across leafy lawn endseq',
#   'startseq dog with brindlecolored coat is running across the yard endseq',
#   'startseq the brown dog is wearing red collar endseq'],
#  '3729525173_7f984ed776.jpg': ['startseq lady sitting on front porch reading book endseq',
#   'startseq person sits at doorstep and reads book endseq',
#   'startseq woman is reading literature and sitting on the front stoop of building endseq',
#   'startseq woman sits and reads in the stoop of wooden door endseq',
#   'startseq woman sits and reads on the front stoop of her building endseq'],
#  '375384566_254c2362d4.jpg': ['startseq couple shops at an antique store endseq',
#   'startseq woman in yellow coat is seated next to standing man in red jacket in diner endseq',
#   'startseq woman sitting on stool wearing tan leather jacket endseq',
#   'startseq three people at asian tattoo parlor endseq',
#   'startseq two men and woman looking at pictures in tattoo parlor endseq'],
#  '3726130458_07df79e969.jpg': ['startseq baseball player dodges ball with his bat high in the air endseq',
#   'startseq baseball player in white uniform is walking to base while crowd of people watch from the bleachers endseq',
#   'startseq baseball player near home plate endseq',
#   'startseq baseball player raises the bat above his head endseq',
#   'startseq baseball player runs to catch the ball endseq'],
#  '396763804_3b7f1e12a8.jpg': ['startseq black and white dog is running through the sand on beach endseq',
#   'startseq brown dog with white paws running on the beach endseq',
#   'startseq there are two dogs running on the beach outside endseq',
#   'startseq two dogs are playing on the beach together endseq',
#   'startseq two dogs run along beach endseq'],
#  '389643437_9a9830a3ba.jpg': ['startseq girl in white cap eats slice of fruit next to girl in blue cap who is eating chocolate endseq',
#   'startseq one young girl eats fruit while another eats chocolate endseq',
#   'startseq two children taking in snack endseq',
#   'startseq two girls sitting in the grass wearing hats eat snacks endseq',
#   'startseq two girls with baseball caps are eating snack outside endseq'],
#  '403523132_73b9a1a4b3.jpg': ['startseq dog is about to get ball that is on orange carpet endseq',
#   'startseq dog on wood floor is staring at yellow ball that is lying on orange carpet endseq',
#   'startseq little brown dog stares at tennis ball on an orange carpet endseq',
#   'startseq puppy playing with tennis ball on an orange rug endseq',
#   'startseq the dog crouched on the orange rug and stared at the tennis ball endseq'],
#  '382090166_be2c2c63e1.jpg': ['startseq white dog and two black dogs playing endseq',
#   'startseq white poodle and black poodles are playing on the grass endseq',
#   'startseq white poodle and two black poodles are playing in the grass on an autumn day endseq',
#   'startseq who is in turn climbing over another black poodle endseq',
#   'startseq two black dogs and one white dog interact endseq'],
#  '374103966_2987706be1.jpg': ['startseq with drink in his right hand endseq',
#   'startseq large man in white dances in the middle of crowd holding beverage in his hand endseq',
#   'startseq robust man with his mouth open in white shirt and glasses holding drink near other people endseq',
#   'startseq bearded overweight man carrying drink and yawning endseq',
#   'startseq dancing endseq'],
#  '381052465_722e00807b.jpg': ['startseq firetruck fights fire endseq',
#   'startseq yellow firetruck is parked next to fire with man on ladder pouring water on it endseq',
#   'startseq firefighters putting out big fire endseq',
#   'startseq fireman fighting fire endseq',
#   'startseq people putting out fire endseq'],
#  '3728256505_7f8db8270d.jpg': ['startseq man jumping onto platform endseq',
#   'startseq man on the edge of wall about to fall off endseq',
#   'startseq man on inline skates does trick on cracked concrete ramp endseq',
#   'startseq man with rollerblades grinding curb endseq',
#   'startseq the man does trick on his skateboard on concrete ramp endseq'],
#  '410042380_517ccee020.jpg': ['startseq blond woman is sitting in brown leather chair while another woman is walking next to store in the background endseq',
#   'startseq person sits in brown chair and is holding bags in their hand endseq',
#   'startseq woman sitting on large brown couch in the middle of mall endseq',
#   'startseq woman is sitting in brown chair in the center of mall endseq',
#   'startseq are in mall endseq'],
#  '375171241_0302ad8481.jpg': ['startseq many people wearing silver leotards are riding bikes on the street endseq',
#   'startseq several men in silver suits are riding bicycles across street endseq',
#   'startseq three people in reflective clothing riding bikes endseq',
#   'startseq three people in reflective white on bikes endseq',
#   'startseq three people in silver suits are riding bikes in the city endseq'],
#  '398413603_166896900f.jpg': ['startseq small white dog jumping to catch tennis ball endseq',
#   'startseq small white dog stands on one leg to catch ball endseq',
#   'startseq white dog is in the air with ball in its mouth endseq',
#   'startseq white dog is leaping into the air to catch ball in its mouth endseq',
#   'startseq white dog with black collar jumps up to catch tennis ball endseq'],
#  '3741462565_cc35966b7a.jpg': ['startseq little girl wearing pink shirt is sitting at the table and drinking milkshake endseq',
#   'startseq small young girl in pink shirt drinking large chocolate milkshake endseq',
#   'startseq young girl dressed in pink with hair barrette pursing her lips at big chocolate milkshake endseq',
#   'startseq young girl is staring at large milkshake in glass endseq',
#   'startseq young girl looks excitedly at large milkshake endseq'],
#  '404890608_33f138aefa.jpg': ['startseq group of young boys fight over bag of trash endseq',
#   'startseq three boys are struggling with one another and reaching for bag of litter endseq',
#   'startseq three boys standing in yard with bunch of paper endseq',
#   'startseq three people are outside with something on the grass endseq',
#   'startseq hold third boys shirt to prevent him from grabbing bag endseq'],
#  '390987167_2d5905b459.jpg': ['startseq hiker moves up snowy mountain endseq',
#   'startseq woman in tank and sunglasses climbs sunny but snowcovered slope endseq',
#   'startseq woman wearing black hat and white sunglasses walks up snowy and steep path endseq',
#   'startseq woman wearing short sleeves and sunglasses is backpacking up snowy mountain cliff endseq',
#   'startseq woman climbing snow covered mountain looking at people behind her endseq'],
#  '374176648_ba4b88c221.jpg': ['startseq there are two people with backpacks walking on the side of grassy hill endseq',
#   'startseq two hikers are trekking across sloping hillside with deep brush in spots endseq',
#   'startseq two mountain climbers climbing up large grassy mountain endseq',
#   'startseq two people are hiking up grassy hill endseq',
#   'startseq two people in heavy clothes are walking up gradual grassy incline endseq'],
#  '3767841911_6678052eb6.jpg': ['startseq baby girl in an orange dress gets wet as she stands next to water sprinkler endseq',
#   'startseq blonde toddler wearing an orange dress is wet and standing beside sprinkler in yard endseq',
#   'startseq child in dress is looking at sprinkler endseq',
#   'startseq little girl in an orange dress is running through the sprinkler in the yard endseq',
#   'startseq little blond girl in orange dress plays in sprinkler endseq'],
#  '408573233_1fff966798.jpg': ['startseq welllit area with his mouth partially open endseq',
#   'startseq dog running fast with his ears flying endseq',
#   'startseq black and brown dog with mouth open upright on green grass endseq',
#   'startseq the black and brown dog is running on the grass endseq',
#   'startseq the black and brown dog is running with something in its mouth endseq'],
#  '3733074526_82aa8d5f8d.jpg': ['startseq girl in costume participates in parade endseq',
#   'startseq girl in red and white costume standing on the street endseq',
#   'startseq girl in red and white costume with onlookers behind her endseq',
#   'startseq small girl dancing in parade wearing bright red and gold clothes endseq',
#   'startseq and gold costumes dancing in parade endseq'],
#  '3758787457_1a903ee1e9.jpg': ['startseq girl dives into the water while another girl watches her endseq',
#   'startseq girl in black twopiece is leaping into the water endseq',
#   'startseq woman in bikini jumping off dock into lake endseq',
#   'startseq woman in black twopiece bathing suit jumping into green water endseq',
#   'startseq woman in black swimsuit is jumping in lake endseq'],
#  '405253184_5f611f3880.jpg': ['startseq animals in the snow endseq',
#   'startseq two black and tan dogs are fighting in snow endseq',
#   'startseq two dogs are laying in the snow with their mouths open endseq',
#   'startseq two dogs try to bite each other while laying in the snow endseq',
#   'startseq two dogs wrestle in the snow endseq'],
#  '407678652_1f475acd65.jpg': ['startseq group of hikers climb rocky terrain endseq',
#   'startseq five backpackers hiking along rocky slope endseq',
#   'startseq five hikers walk down the hillside endseq',
#   'startseq five people with backpacks hiking down rocky hill endseq',
#   'startseq the hikers descend on the mountain endseq'],
#  '374828031_9d087da5cf.jpg': ['startseq climber is scaling reddish colored rock face endseq',
#   'startseq lone man climbing huge rock wall endseq',
#   'startseq man climbing cliff endseq',
#   'startseq man climbing rock cliff endseq',
#   'startseq the man is scaling large copper boulder endseq'],
#  '380515798_c2abbf46b0.jpg': ['startseq crowd walks along sidewalk of farmers market endseq',
#   'startseq and vendors endseq',
#   'startseq woman looks over table of organic vegetables at farmer market endseq',
#   'startseq men and women walking on the sidewalk outside marketplace endseq',
#   'startseq street with many white tents with display table with people walking nearby endseq'],
#  '408627152_1feaa4b94e.jpg': ['startseq dog in life jacket sitting on boat with man in the cockpit endseq',
#   'startseq man looking at his small white dog wearing an orange life jacket endseq',
#   'startseq shite dog in an orange life vest looking at man in blue shirt while riding in boat endseq',
#   'startseq white dog in life jacket looks at man in boat endseq',
#   'startseq white dog with life vest accompanies man in boat endseq'],
#  '3729405438_6e79077ab2.jpg': ['startseq bicycler balances his bike on rail endseq',
#   'startseq biker is riding down the stairs on his bike at night endseq',
#   'startseq boy rides his red bicycle down the handrail of staircase in city endseq',
#   'startseq guy grinding rail in park on his bike endseq',
#   'startseq trick bicyclist grinds down handrail endseq'],
#  '386160015_d4b31df68e.jpg': ['startseq brown dog playing play wrestling with black dog on snow covered land endseq',
#   'startseq the two dogs are fighting outside in the snow endseq',
#   'startseq two brown dogs playing in snow endseq',
#   'startseq two dogs are wrestling in snow covered field endseq',
#   'startseq two dogs playing on snow covered ground endseq'],
#  '381275595_b429fd1639.jpg': ['startseq brown dog is chewing on bone with stuffed animal underneath it endseq',
#   'startseq dog chews on bone endseq',
#   'startseq big brown dog chews on bone lying down endseq',
#   'startseq big hairy dog chews on bone while lying on furry toy endseq',
#   'startseq brown dog chews on bone while laying on the rug endseq'],
#  '391020801_aaaae1e42b.jpg': ['startseq man gesticulates endseq',
#   'startseq man in white shirt holding both hands out endseq',
#   'startseq an elderly male wearing white wal mart smock with his arms and hand extended in front of him endseq',
#   'startseq old man in wall mart unifrom holds his arms out to the camera endseq',
#   'startseq walmart worker wearing white coat endseq'],
#  '407008823_bdd7fc6ed5.jpg': ['startseq climber is making his way up snowy mountainside endseq',
#   'startseq lone person jumping through the air from one snowy mountain to another endseq',
#   'startseq man doing tricks in the snow endseq',
#   'startseq man dressed in snowgear takes leap into snowcovered ravine endseq',
#   'startseq people jump over mountain crevasse on rope endseq'],
#  '375392855_54d46ed5c8.jpg': ['startseq woman in yellow and black outfit is skiing endseq',
#   'startseq woman skier in yellow and black races down the slope in front of the snowcovered trees endseq',
#   'startseq woman skiing down slope endseq',
#   'startseq woman snow skiing in yellow jacket and black pants endseq',
#   'startseq the woman in the yellow jacket is riding on snow skates endseq'],
#  '403678611_73978faed7.jpg': ['startseq man in cap with goatee leans against the window and reads magazine endseq',
#   'startseq man sitting on an empty train endseq',
#   'startseq man with black hat and black beard is reading magazine sitting on blue bench endseq',
#   'startseq man with hat sits in booth and reads endseq',
#   'startseq the man reading magazine is sitting in the large room endseq'],
#  '3741827382_71e93298d0.jpg': ['startseq boy in green shirt above something blue endseq',
#   'startseq small boy getting tossed into the air endseq',
#   'startseq young boy jumps around on blue mat with halfsmile on his face endseq',
#   'startseq young boy plays in front of blue object endseq',
#   'startseq the boy wearing the green shirt is climbing on blue inflatable endseq'],
#  '3728015645_b43a60258b.jpg': ['startseq man is posed standing on one hand on skateboard ramp endseq',
#   'startseq man on inline skates in midair endseq',
#   'startseq skateboarder wearing white cap is doing stunt in city skate park endseq',
#   'startseq young man is skateboarding on ramp and is standing on one arm endseq',
#   'startseq man standing on one arm with feet in the air on playground equipment with body of water in the background endseq'],
#  '3726168984_1fa2c8965b.jpg': ['startseq black dog is colliding with golden dog that has something in its mouth endseq',
#   'startseq black dog trying to mate with brown dog endseq',
#   'startseq brown dog and yellow dog play fight over plastic bottle endseq',
#   'startseq brown dog is climbing over golden dog that is carrying bottle in its mouth endseq',
#   'startseq two dogs play with bottle endseq'],
#  '3756150099_50882fc029.jpg': ['startseq boy peeks his head through painted picture endseq',
#   'startseq child poses within mock pumpkin head endseq',
#   'startseq child stand behind cutout picture endseq',
#   'startseq little boy with face inside painted pumpkin endseq',
#   'startseq the child has his head in the frame of the painting endseq'],
#  '396360611_941e5849a3.jpg': ['startseq man stands alone on the rocks endseq',
#   'startseq man stands on rocky cliff overlooking body of water endseq',
#   'startseq person is standing on jagged rocks above the water below endseq',
#   'startseq person with backpack stands on rocky bank beside body of water endseq',
#   'startseq person standing on rocky edge of water with hilly land in background endseq'],
#  '3728164558_52729baefa.jpg': ['startseq two people leaning against railing outside the enterance of building endseq',
#   'startseq two people standing on porch endseq',
#   'startseq two woman stand near door endseq',
#   'startseq two women standing outside community library endseq',
#   'startseq two women stand outside library endseq'],
#  '427936315_0b8f7b8d23.jpg': ['startseq brown dog is chasing red frisbee across grassy field endseq',
#   'startseq dog leaps in the air to catch red frisbee endseq',
#   'startseq dog runs for red frisbee endseq',
#   'startseq dog surrounded by trees runs to catch frisbee endseq',
#   'startseq the large brown dog is running through the grass to catch red frisbee endseq'],
#  '451081733_40218cec31.jpg': ['startseq man on the beach in jeans looking at his camera endseq',
#   'startseq shirtless guy turned around videotaping something at the beach endseq',
#   'startseq barechested man filming at the beach endseq',
#   'startseq the man is wearing rolled up blue jeans and holding video camera on stone beach endseq',
#   'startseq the shirtless man used his camera while sitting on the rocky beach endseq'],
#  '436013859_793d870b6f.jpg': ['startseq barbeque in the background endseq',
#   'startseq brown dog is trying to catch flying disk but missed it endseq',
#   'startseq dog is twisting in the air as it tries to catch frisbee endseq',
#   'startseq brown dog plays with frisbee endseq',
#   'startseq the brown dog dives backwards to catch the football endseq'],
#  '416788726_5b4eb1466e.jpg': ['startseq family of five is watching performer standing on stepstool endseq',
#   'startseq group of people watch man standing on stool dressed in thong endseq',
#   'startseq halfnaked performer is performing for small crowd outside endseq',
#   'startseq man in small bathing suit standing on stool at tourist location endseq',
#   'startseq mostly nude man standing on stool while family of look at him questioningly endseq'],
#  '425088533_a460dc4617.jpg': ['startseq little boy in red sweater is climbing tree endseq',
#   'startseq little boy in red is climbing tree endseq',
#   'startseq small child in tree endseq',
#   'startseq toddler in red sweatshirt and grey sweatpants in the branches of tree endseq',
#   'startseq young boy in red shirt plays in tree endseq'],
#  '416106657_cab2a107a5.jpg': ['startseq fluffy white dog runs through the woods with his ears flapping in the breeze endseq',
#   'startseq small white dog is running across grassy field endseq',
#   'startseq  endseq',
#   'startseq white dog wearing red harness runs though the woods endseq',
#   'startseq the little white dog wearing the red collar is running in the grass endseq'],
#  '446514680_ff5ca15ece.jpg': ['startseq two brown dogs are fighting and they are both wearing red endseq',
#   'startseq two brown dogs rough house outside endseq',
#   'startseq two brown dogs wearing red collars look at each other while running along dirt field endseq',
#   'startseq two dogs play together endseq',
#   'startseq two large brown short haired dogs with collars play chase in field endseq'],
#  '416960865_048fd3f294.jpg': ['startseq hiker in red on snowy peak endseq',
#   'startseq person in red jacket and red hardhat stands near mountain endseq',
#   'startseq person wearing red jacket and helmet walks up near the large rock endseq',
#   'startseq woman wearing red work man hat and red jacket is hiking in the snow topped mountains endseq',
#   'startseq the person wearing the red hardhat is on the mountain endseq'],
#  '444057017_f1e0fcaef7.jpg': ['startseq little girl gets her picture taken while on the merrygoround endseq',
#   'startseq little girl in pink clothes holding yellow rods endseq',
#   'startseq little girl on piece of playground equipment endseq',
#   'startseq little girl sitting on playground ride endseq',
#   'startseq young girl looks up as she rides on merrygoround endseq'],
#  '418796494_bdb441de42.jpg': ['startseq dachshund puppy jumps on bed endseq',
#   'startseq puppy jumps on bed with purple sheets endseq',
#   'startseq puppy on bed with blue sheets and pillow endseq',
#   'startseq small black and brown puppy is looking up endseq',
#   'startseq the dog is on the bed endseq'],
#  '432496659_f01464d9fb.jpg': ['startseq brown and white dog is walking through some wasteland endseq',
#   'startseq collie runs across yard in the springtime endseq',
#   'startseq collie surrounded by leafless bushes endseq',
#   'startseq dog that looks like lassie walking in the fields endseq',
#   'startseq the dog is in front of some bushes endseq'],
#  '425518464_a18b87c563.jpg': ['startseq person wearing white hooded sweatshirt covered with blanket sitting on bench reading endseq',
#   'startseq woman reads paper on bench in park endseq',
#   'startseq woman sits on bench reading newspaper endseq',
#   'startseq the person wearing the white sheet and white hoodie sits on the bench reading endseq',
#   'startseq woman wrapped in blanket sits on bench and reads in park endseq'],
#  '428408242_b32faf2240.jpg': ['startseq brown and white dog is jumping with red frisbee in its mouth endseq',
#   'startseq holding flexible frisbee endseq',
#   'startseq dog running with frisbee endseq',
#   'startseq fit dog leaps with disc in its mouth endseq',
#   'startseq the brown and white bog has red item in its mouth endseq'],
#  '437404867_209625774d.jpg': ['startseq woman is sitting on sidewalk with cellphone at her ear endseq',
#   'startseq woman rests on the curb of city street while talking on her cellphone endseq',
#   'startseq woman sits on the curb while talking on her cellphone endseq',
#   'startseq woman sits on the edge of sidewalk with garbage bin beside her endseq',
#   'startseq woman sits on the curb talking on cellphone endseq'],
#  '434433505_966e50e17d.jpg': ['startseq person does trick on skateboard endseq',
#   'startseq skateboarder is doing trick in midair endseq',
#   'startseq he is doing tricks on the skateboard endseq',
#   'startseq there is the bottom of skateboard off the ground with someone in blue jeans holding it endseq',
#   'startseq grabs the board while in the air endseq'],
#  '415118186_64defc96f3.jpg': ['startseq man in black looks out over snowy landscape endseq',
#   'startseq man looks out over frozen tundra endseq',
#   'startseq standing and looking out over snowy scene endseq',
#   'startseq person in dark clothing takes snapshot of snowy scene endseq',
#   'startseq person taking pictures outside in the snow endseq'],
#  '426191845_1e979e9345.jpg': ['startseq dog is playing by itself on beach that has recently seen snowfall endseq',
#   'startseq dog is running in the dirt and snow endseq',
#   'startseq dog running on the sand endseq',
#   'startseq dog walking along snow drift endseq',
#   'startseq yellow dog is running down sandy and snowy hill endseq'],
#  '418357172_bdddf71d32.jpg': ['startseq black and tan dog is walking over shoreline with many small sand hills endseq',
#   'startseq brown and black dog running on shore near the beach endseq',
#   'startseq dog in the beach endseq',
#   'startseq dog walking on wet beach endseq',
#   'startseq small black and tan dog walking in wet sand endseq'],
#  '428483413_b9370baf72.jpg': ['startseq blond girl standing in front of large metal fan endseq',
#   'startseq man and woman walking past record shop endseq',
#   'startseq woman and man are passing by window displaying record endseq',
#   'startseq woman and man stand outside store endseq',
#   'startseq woman with dirty blonde hair and sunglasses and man with dark hair stand in front of record store endseq'],
#  '42637986_135a9786a6.jpg': ['startseq silhouette of two people sitting on dock at sunset endseq',
#   'startseq two people are sitting on wooden dock on lake at sunset endseq',
#   'startseq two people sit on dock with sunset in the background endseq',
#   'startseq two people sit on the pier together and look out at the ocean endseq',
#   'startseq two people sitting on dock under lamp post with clouds in the sky beyond them endseq'],
#  '429174232_ddd4ff5e0b.jpg': ['startseq an alley open to couple of people walking by endseq',
#   'startseq the legs of several people walking past an alley endseq',
#   'startseq two pairs of legs walk past the end of an alley between two brick buildings endseq',
#   'startseq seen from alleyway endseq',
#   'startseq view through an alley of pedestrians passing by endseq'],
#  '412056525_191724b058.jpg': ['startseq child is eating something very close to the camera while other children sit at table behind him endseq',
#   'startseq little boy prestends to punch another kid in the temple while they are eating lunch endseq',
#   'startseq asian children eating together endseq',
#   'startseq three children eating food at table endseq',
#   'startseq two asian children are looking at another child who is eating in restaurant endseq'],
#  '421316045_ae7a1eb4bc.jpg': ['startseq child in an orange sweater is playing with child in blue clothes on white couch under red painting endseq',
#   'startseq kid in yellow shirt wrestles with denim wearing kid on the white couch endseq',
#   'startseq two kids are wrestling on white sofa endseq',
#   'startseq two toddlers wrestle on white couch endseq',
#   'startseq two young boys playing on white sofa endseq'],
#  '448252603_7d928c900e.jpg': ['startseq boy pointing in direction on dirt road endseq',
#   'startseq boy with backpack sits on trail and points endseq',
#   'startseq man points his finger to the path ahead as he sits on the dirt path endseq',
#   'startseq man with backpack is sitting in dirt road and pointing toward the horizon endseq',
#   'startseq young man sitting in the middle of dirt road pointing up the road endseq'],
#  '442220883_ff3d6e507f.jpg': ['startseq brown dog has white toy in its mouth endseq',
#   'startseq dog holding white stuffed animal endseq',
#   'startseq tan dog hangong on to white plushie toy endseq',
#   'startseq yellow dog is chewing on white stuffed toy endseq',
#   'startseq the dog is holding stuffed toy in his mouth endseq'],
#  '417966898_a04f9b5349.jpg': ['startseq two girls hanging upside down on park structure endseq',
#   'startseq two girls hang upside down at park endseq',
#   'startseq two girls play on jungle gym endseq',
#   'startseq two little girls are hanging upsidedown on climbing frame endseq',
#   'startseq two young girls playing outside on the playground endseq'],
#  '438639005_208bc59b0b.jpg': ['startseq boy in red and girl pink are walking through low cut field endseq',
#   'startseq the little boy and little girl are walking side by side endseq',
#   'startseq two small children walk away in field endseq',
#   'startseq two small children walking in field endseq',
#   'startseq two young children are walking across an open field endseq'],
#  '426920445_d07d1fd0f7.jpg': ['startseq black and white dog runs on soft green grass endseq',
# ...
#   'startseq green leaves endseq'],
#  '86542183_5e312ae4d4.jpg': ['startseq two boys play hockey on frozen pond endseq',
#   'startseq two children are playing ice hockey on frozen ground outside endseq',
#   'startseq two kids play game together with sticks in the snow endseq',
#   'startseq two kids play hockey in the snow endseq',
#   'startseq two kids play hockey on pond endseq'],
#  '795081510_53fd17d101.jpg': ['startseq looking out at ferry endseq',
#   'startseq couple standing on the deck of boat watching the water endseq',
#   'startseq man embraces woman as they look over the railing out over the water at ship endseq',
#   'startseq couple overlooking metal rail with water and boat int he background endseq',
#   'startseq the couple is together looking at the large ship in the ocean endseq'],
#  '801607443_f15956d1ce.jpg': ['startseq one climber is sitting on the rock overlooking the ocean whilst another climber is on her way up endseq',
#   'startseq two people are on rock overlooking the ocean endseq',
#   'startseq two people climb rock overhanging water endseq',
#   'startseq two people climb rocks over some water endseq',
#   'startseq two people rock climbing near water endseq'],
#  '861661418_8a37024ace.jpg': ['startseq brown dog picks up twig from stone surface endseq',
#   'startseq brown puppy chewing on stick endseq',
#   'startseq dog with big ears is holding small stick in its mouth endseq',
#   'startseq puppy has stick in its mouth endseq',
#   'startseq puppy with big ears chewing on stick endseq'],
#  '883040210_3c4a10f030.jpg': ['startseq climber is sillhouetted against the sky and rocks as he hangs by rope from another rock endseq',
#   'startseq person hangs from safety rope as he climbs down large cliff endseq',
#   'startseq person is abseiling down rock face attached to rope endseq',
#   'startseq person jumping down rope on cliff endseq',
#   'startseq the man repels down the side of cliff endseq'],
#  '827941668_2e4ac6cb39.jpg': ['startseq child is splashing in the water at the beach endseq',
#   'startseq girl is playing in the ocean at dusk endseq',
#   'startseq kid splashes in the ocean endseq',
#   'startseq person is standing in water with it splashing all around them while another person lingers in the background endseq',
#   'startseq two children playing in the surf endseq'],
#  '875731481_a5a0a09934.jpg': ['startseq woman wearing brightly colored costume stands onstage endseq',
#   'startseq feather headed wearing women competing on stage in some sort of pagent endseq',
#   'startseq costumed women perform outdoors endseq',
#   'startseq several women dressed in colorful costumes near city hall building endseq',
#   'startseq women in costume stand on stage endseq'],
#  '957682378_46c3b07bcd.jpg': ['startseq brown dog and black dog run into each other in the grass endseq',
#   'startseq brown dog is grabbing the collar of black dog endseq',
#   'startseq dark black dog is playing with light brown dog in backyard endseq',
#   'startseq two dogs are wrestling in field endseq',
#   'startseq two dogs are wrestling in the park endseq'],
#  '947664583_7c63172366.jpg': ['startseq child jumps into pool as man looks on endseq',
#   'startseq girl with swimmies on is jumping into pool endseq',
#   'startseq little girl wearing orange arm floats jumping into pool endseq',
#   'startseq little girl with inflatable armbands is jumping into the pool endseq',
#   'startseq young girl with water wings leaps into crowded pool endseq'],
#  '862156271_3eacea90a8.jpg': ['startseq girls with orange hair standing on the street with some kind of bottle in their hand endseq',
#   'startseq two girls walking in the street endseq',
#   'startseq two girls walking next to each other and talking endseq',
#   'startseq two teenage girls dressed like hippies walk and talk endseq',
#   'startseq are standing next to each other while one holds bottle endseq'],
#  '927420680_6cba7c040a.jpg': ['startseq man is walking by trees in front of the city skyline endseq',
#   'startseq man walking next to an extremely large tree trunk endseq',
#   'startseq tall trees endseq',
#   'startseq someone in light shirt is walking past several large trees overlooking city endseq',
#   'startseq the man walks among the large trees endseq'],
#  '847782643_57248bbdab.jpg': ['startseq two children laying on the floor with group of wooden blocks above their heads endseq',
#   'startseq two children re laying on rug with some wooden bricks laid out in square between them endseq',
#   'startseq two kids lie on rug near wooden blocks and smile endseq',
#   'startseq two little girls lie on the carpet next to an made of wooden blocks endseq',
#   'startseq two young girls lay on the carpet next to wooden blocks endseq'],
#  '812196663_0c969970b5.jpg': ['startseq black boy and white boy in swimming trunks are hugging each other on beach or lake endseq',
#   'startseq white boy and black boy embrace endseq',
#   'startseq two boys in red swim trunks hold each other in the water endseq',
#   'startseq two kids are hugging playfully in shallow water endseq',
#   'startseq two kids are standing in the ocean hugging each other endseq'],
#  '947969010_f1ea572e89.jpg': ['startseq shaking off water with stick in its mouth endseq',
#   'startseq black dog with red collar has an item in his mouth and is climbing out of pool endseq',
#   'startseq brown dog climbing out of pool with stick in his mouth endseq',
#   'startseq dog with stick in its mouth climbs out of the water endseq',
#   'startseq the dog is climbing out of the water with stick endseq'],
#  '93922153_8d831f7f01.jpg': ['startseq woman climbs up cliff endseq',
#   'startseq woman rock climber scales cliff far above pastures endseq',
#   'startseq woman rockclimbing on cliff endseq',
#   'startseq woman rockclimbs in rural area endseq',
#   'startseq woman climbing cliff in rural area endseq'],
#  '823675317_b5fbdb17b3.jpg': ['startseq boy in blue carries bucket endseq',
#   'startseq boy in blue swim trunks carries blue bucket down crowded beach endseq',
#   'startseq child walks on the beach with bucket endseq',
#   'startseq the boy in the blue shorts is carrying bucket on the beach endseq',
#   'startseq young boy in blue shorts at the beach endseq'],
#  '861795382_5145ad433d.jpg': ['startseq boy in blue shirt and shorts jumping bike with ramp endseq',
#   'startseq boy in blue tshirt is taking an orange bicycle over jump in the street endseq',
#   'startseq little boy in blue doing bike jumps endseq',
#   'startseq kid in blue shirt doing tricks on bike endseq',
#   'startseq young boy on bicycle jumping off ramp endseq'],
#  '95734038_2ab5783da7.jpg': ['startseq man on bike nest to river endseq',
#   'startseq man rides bicycle on rocky path beside lake in the mountains endseq',
#   'startseq man rides bicycle on rocky trail along large river endseq',
#   'startseq man stands astride bike on rocky trail by lake endseq',
#   'startseq the man on the bike is sitting on gravel hill endseq'],
#  '862187579_9faf4a51e0.jpg': ['startseq man wearing glasses is staring off into space endseq',
#   'startseq man with glasses is standing in front of building endseq',
#   'startseq man with sunglasses looking straight ahead endseq',
#   'startseq man with sunglasses standing by white and red building with very blue sky above endseq',
#   'startseq the man wearing the purple shirt is in the shadows endseq'],
#  '842961005_692737888e.jpg': ['startseq girl walking with her grey umbrella endseq',
#   'startseq woman holding an umbrella is standing near parking meter endseq',
#   'startseq woman is walking down the street holding an umbrella endseq',
#   'startseq woman with blue umbrella stands next to parking meter endseq',
#   'startseq holds her blue umbrella over her head while walking on sidewalk near parking meter endseq'],
#  '97406261_5eea044056.jpg': ['startseq calico cat raising its paws towards dog with an open mouth endseq',
#   'startseq cat swatting at doberman dog endseq',
#   'startseq dog and cat are fighting on chair endseq',
#   'startseq multicolor cat fighting with black and brown dog in red collar endseq',
#   'startseq the yellow and black cat and the brown and black dog are fighting endseq'],
#  '997338199_7343367d7f.jpg': ['startseq person stands near golden walls endseq',
#   'startseq woman behind scrolled wall is writing endseq',
#   'startseq woman standing near decorated wall writes endseq',
#   'startseq the walls are covered in gold and patterns endseq',
#   'startseq decorated walls endseq'],
#  '985067019_705fe4a4cc.jpg': ['startseq boy goes down an inflatable slide endseq',
#   'startseq boy in red slides down an inflatable ride endseq',
#   'startseq boy is sliding down in red shirt endseq',
#   'startseq child going down an inflatable slide endseq',
#   'startseq is looking off camera endseq'],
#  '975131015_9acd25db9c.jpg': ['startseq blond boy petting tiger endseq',
#   'startseq boy pets sleeping tiger endseq',
#   'startseq boy pets sleeping tiger while another tiger sleeps behind him endseq',
#   'startseq little blonde boy is petting resting tiger endseq',
#   'startseq little boy is petting tiger that is laying down endseq'],
#  '990890291_afc72be141.jpg': ['startseq man does wheelie on his bicycle on the sidewalk endseq',
#   'startseq man is doing wheelie on mountain bike endseq',
#   'startseq man on bicycle is on only the back wheel endseq',
#   'startseq asian man in orange hat is popping wheelie on his bike endseq',
#   'startseq man on bicycle riding on only one wheel endseq'],
#  '98377566_e4674d1ebd.jpg': ['startseq two brown and white dogs lift their ears and look through fence endseq',
#   'startseq two little dogs looking out of their cage endseq',
#   'startseq two small dogs are in cage outside endseq',
#   'startseq two small dogs in cage endseq',
#   'startseq two white and brown dogs up against fence endseq'],
#  '979201222_75b6456d34.jpg': ['startseq two girls are walking arm in arm past an amusement arcade endseq',
#   'startseq two girls are walking away from the camera under walkway endseq',
#   'startseq two girls in shorts walk towards casino signs endseq',
#   'startseq two teenage girls walking down mall breezeway endseq',
#   'startseq two women walk on the sidewalk endseq'],
#  '978580450_e862715aba.jpg': ['startseq blonde child swims endseq',
#   'startseq boy is swimming in open water endseq',
#   'startseq child submerges from the water endseq',
#   'startseq kid comes up from the water endseq',
#   'startseq the small child comes up from underwater endseq'],
#  '989754491_7e53fb4586.jpg': ['startseq girl in pool wearing goggles and surrounded by other children endseq',
#   'startseq girl in green goggles in pool with three other children endseq',
#   'startseq red haired girl making peace sign is wearing neon green glasses and floaties and playing in the pool with other kids endseq',
#   'startseq redheaded girl offers the peace sign as she swims in the pool with floaties endseq',
#   'startseq young girl with goggles and floaties poses for the camera as she plays in pool endseq'],
#  '997722733_0cb5439472.jpg': ['startseq man in pink shirt climbs rock face endseq',
#   'startseq man is rock climbing high in the air endseq',
#   'startseq person in red shirt climbing up rock face covered in assist handles endseq',
#   'startseq rock climber in red shirt endseq',
#   'startseq rock climber practices on rock climbing wall endseq'],
#  '99679241_adc853a5c0.jpg': ['startseq grey bird stands majestically on beach while waves roll in endseq',
#   'startseq large bird stands in the water on the beach endseq',
#   'startseq tall bird is standing on the sand beside the ocean endseq',
#   'startseq water bird standing at the ocean edge endseq',
#   'startseq white crane stands tall as it looks out upon the ocean endseq'],
#  '989851184_9ef368e520.jpg': ['startseq black dog has dumbbell in his mouth endseq',
#   'startseq black dog has dumbbell in his mouth looking at the person wearing blue endseq',
#   'startseq black dog holding weight in its mouth stands next to person endseq',
#   'startseq black dog holds small white dumbbell in its mouth endseq',
#   'startseq the black dog has toy in its mouth and person stands nearby endseq'],
#  '979383193_0a542a059d.jpg': ['startseq group of six children sit at wooden table endseq',
#   'startseq group of young asian children pose for picture at table endseq',
#   'startseq sit at table for picture endseq',
#   'startseq six children at table endseq',
#   'startseq six small children sitting at desk endseq'],
#  '99171998_7cc800ceef.jpg': ['startseq group is sitting around snowy crevasse endseq',
#   'startseq group of people sit atop snowy mountain endseq',
#   'startseq group of people sit in the snow overlooking mountain scene endseq',
#   'startseq five children getting ready to sled endseq',
#   'startseq five people are sitting together in the snow endseq'],
#  '97731718_eb7ba71fd3.jpg': ['startseq cart containig two men being pulled by horses in the rain endseq',
#   'startseq horse driven carriage running through rainstorm endseq',
#   'startseq black and white horses carry cart with people through the rain endseq',
#   'startseq people enjoy horse draw open carriage in the rain endseq',
#   'startseq through the rain endseq'],
#  '97577988_65e2eae14a.jpg': ['startseq man mountain climbing up an icy mountain endseq',
#   'startseq an climber is ascending an ice covered rock face endseq',
#   'startseq person in orange climbs sheer cliff face covered in snow and ice endseq',
#   'startseq person in yellow jacket is climbing up snow covered rocks endseq',
#   'startseq there is climber scaling snowy mountainside endseq'],
#  '974924582_10bed89b8d.jpg': ['startseq child is running away from plastic pool and an adult on rural setting endseq',
#   'startseq child is running away from woman standing by paddling pool endseq',
#   'startseq child playing with water hose while woman records with camcorder endseq',
#   'startseq woman and her son are playing outside by kiddie pool endseq',
#   'startseq woman watches child play near small pool endseq'],
#  '973827791_467d83986e.jpg': ['startseq little kid splashes around in the kiddie pool while lady watches endseq',
#   'startseq woman dumping water on small child who is in pool endseq',
#   'startseq woman is throwing bucket of water over baby in the paddling pool endseq',
#   'startseq woman is throwing water on child in plastic swimming pool in rural area endseq',
#   'startseq child slides into wading pool full of water while an adult tosses bucket of water on them endseq'],
#  '976392326_082dafc3c5.jpg': ['startseq woman and little girl sit on desert rock endseq',
#   'startseq young girl and older person are sitting near the top of rock formation endseq',
#   'startseq two girls sit on large rock endseq',
#   'startseq two people are sitting on huge rock formation endseq',
#   'startseq two people sit in the distance on an unusual rock formation endseq'],
#  '972381743_5677b420ab.jpg': ['startseq as others watch endseq',
#   'startseq girl dressed in black and white with mime makeup stands in the middle of street with white umbrella and black top hat in her hand endseq',
#   'startseq performer dancing in the streets wearing an exotic outfit endseq',
#   'startseq woman with shaved head dressed in black and white in parade endseq',
#   'startseq the lady in the street is wearing white and black costume and is carrying white umbrella endseq'],
#  '977856234_0d9caee7b2.jpg': ['startseq brown dog in pink shirt runs through field endseq',
#   'startseq hairy dog with pink shirt running through field endseq',
#   'startseq longhaired dog wearing pink vest and running endseq',
#   'startseq brown dog in pink sweater runs on yellow grass endseq',
#   'startseq dog with pink jacket running in field endseq'],
#  '987907964_5a06a63609.jpg': ['startseq one brown and white dog chasing black and white dog through the grass endseq',
#   'startseq the two dogs are running through the grass endseq',
#   'startseq two cocker spaniels running through the grass endseq',
#   'startseq two dogs are running through green yard endseq',
#   'startseq two dogs are running through the grass near house and trees endseq'],
#  ...}

# %%
# test our list, create imgs set from caption again before run this code
img = random.choice(list(imgs))
caps = img_dict[img]
print(f'img: {img}')
print(f'cap lenght: {len(caps)}')
print(caps)
# Out:
# img: 716597900_b72c58362c.jpg
# cap lenght: 5
# ['startseq an adult and three children walk along the beach endseq', 'startseq woman and three children walk on the beach in line endseq', 'startseq woman is walking along the beach with three children following behind her endseq', 'startseq woman walks along the beach as three children follow her in line endseq', 'startseq the boys follow their mother on the beach endseq']

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import InceptionV3

# %%
# load image and proprocess into Inception v3
def preprocess(image_path):
    # convert all the images to size 299x299 as excepted by the inception v3 model
    img = image.load_img(image_path,target_size=  (299,299))
    # convert image into array
    x= image.img_to_array(img)
    # add 1 dimension as 1 simple
    x = np.expand_dims(x,axis =0) # (n_sample,width,height,colors)
    # preprocess_input
    x = preprocess_input(x) # scale it from 0-255 to 0-1 
    return x

# %%
# test your preprocess input
img = random.choice(list(imgs))
x  = preprocess('/content/drive/MyDrive/Flickr8k/Images/' + img)
for cap in img_dict[img]:
    print(cap)
plt.imshow(x[0])
plt.title(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# startseq float representing the times of hanging is shown in the back of truck endseq
# startseq man in judge costume stand on red truck and hangs dummy endseq
# startseq man dressed as judge pretending to hang another man on top of truck endseq
# startseq three people in costumes stand on the back of pickup truck endseq
# startseq three people stand on the back of truck endseq
# Text(0.5, 1.0, '2661294969_1388b4738c.jpg')

# %%
# load inception v3 model
model = InceptionV3(weights = 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 1s 0us/step
# 96124928/96112376 [==============================] - 1s 0us/step

# %%
# check model summary
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#
#  batch_normalization_80 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
from keras.models import Model

# %%
# remove the last layer for feature extraction
feature_extractor = Model(model.input,model.layers[-2].output) # -1 is the last
feature_extractor.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#
#  conv2d_80 (Conv2D)             (None, 8, 8, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# image embedding with feature_extractor
def encode(image,feature_extractor):
    image = preprocess(image) # convert image model input
    feature_vector = feature_extractor.predict(image) # get the encoding vector for the image
    feature_vector = np.ravel(feature_vector) # reshape (1,2048) to (2048,)
    return feature_vector

img = random.choice(list(imgs))
feature_vector = encode('/content/drive/MyDrive/Flickr8k/Images/' + img,feature_extractor)
print(feature_vector.shape)
# Out:
# (2048,)

# %%
# split train-valid-test
full_images = list(imgs)
train_images = full_images[:6000]
valid_images = full_images[6000:7000]
test_images = full_images[7000:]
print(f'full_images: {len(full_images)}')
print(f'train_images: {len(train_images)}')
print(f'valid_images: {len(valid_images)}')
print(f'test_images: {len(test_images)}')
# Out:
# full_images: 8091
# train_images: 6000
# valid_images: 1000
# test_images: 1091

# %%
'3737711435_113ccd0a52.jpg' in train_images
# Out:
# True

# %%
from time import time
from tqdm import tqdm

# %%
# encode all image in train set
start = time()
encoding_train = {}
for img in tqdm(train_images):
    encoding_train[img] = encode('/content/drive/MyDrive/Flickr8k/Images/' + img,feature_extractor)
print("Time taken in seconds = ",time()-start)
# Out:
# 100%|██████████| 6000/6000 [30:39<00:00,  3.26it/s]
# Time taken in seconds =  1839.2253859043121

# %%
from pickle import dump,load

# %%
# store your encode image
with open('./encoded_train_images.pkl','wb') as encoded_pickle:
    dump(encoding_train,encoded_pickle)

# %%
# move to drive
# !cp ./encoded_train_images.pkl /content/drive/MyDrive

# %%
# encode all image in valid set
start = time()
encoding_valid = {}
for img in tqdm(valid_images):
    encoding_valid[img] = encode('/content/drive/MyDrive/Flickr8k/Images/' + img,feature_extractor)
print("Time taken in seconds = ",time()-start)
# Out:
# 100%|██████████| 1000/1000 [05:04<00:00,  3.28it/s]
# Time taken in seconds =  304.85265350341797

# %%
# store your encode image
with open('./encoded_valid_images.pkl','wb') as encoded_pickle:
    dump(encoding_valid,encoded_pickle)

# %%
# move to drive
# !cp ./encoded_valid_images.pkl /content/drive/MyDrive

# %%
# encode all image in test set
start = time()
encoding_test = {}
for img in tqdm(test_images):
    encoding_test[img] = encode('/content/drive/MyDrive/Flickr8k/Images/' + img,feature_extractor)
print("Time taken in seconds = ",time()-start)
# Out:
# 100%|██████████| 1091/1091 [05:39<00:00,  3.21it/s]
# Time taken in seconds =  339.9790349006653

# %%
# store your encode image
with open('./encoded_test_images.pkl','wb') as encoded_pickle:
    dump(encoding_test,encoded_pickle)

# %%
# move to drive
# !cp ./encoded_test_images.pkl /content/drive/MyDrive

# %%
# load train-valid-test feature
train_features = load(open('/content/encoded_train_images.pkl','rb'))
print(f'train features: {len(train_features)}')
valid_features = load(open('/content/encoded_valid_images.pkl','rb'))
print(f'valid features: {len(valid_features)}')
test_features = load(open('/content/encoded_test_images.pkl','rb'))
print(f'test features: {len(test_features)}')
# Out:
# train features: 6000
# valid features: 1000
# test features: 1091

# %%
# create a dict of training captions
all_train_captions = []
for img in train_images:
  captions = img_dict[img]
  for caption in captions:
    all_train_captions.append(caption)
print(f'all train captions: {len(all_train_captions)}')
# Out:
# all train captions: 30000

# %%
# create a list of all valid captions
all_valid_captions = []
for img in valid_images:
  captions = img_dict[img]
  for caption in captions:
    all_valid_captions.append(caption)
print(f'all valid captions: {len(all_valid_captions)}')
# Out:
# all valid captions: 5000

# %%
# create a list of all test captions
all_test_captions = []
for img in test_images:
  captions = img_dict[img]
  for caption in captions:
    all_test_captions.append(caption)
print(f'all test captions: {len(all_test_captions)}')
# Out:
# all test captions: 5455

# %%
# create a train dictionary and just take the word apear 10 time
word_count_threshold = 10
word_counts = {}
for sent in all_train_captions:
  for word in sent.split(' '):
    word_counts[word] = word_counts.get(word,0) + 1  # count the word 

vocab = [word for word in word_counts if word_counts[word] >= word_count_threshold]
print('preprocessed words %d -> %d' % (len(word_counts),len(vocab)))
# Out:
# preprocessed words 7529 -> 1609

# %%
ixtoword = {} # id_number : word
wordtoix = {} # word : id_number
ix = 1
for word in vocab:
  wordtoix[word] = ix
  ixtoword[ix] = word 
  ix +=1

# %%
vocab_size = len(ixtoword) +1 # add 1 for padding word " "
vocab_size
# Out:
# 1610

# %%
# create a dictionary of the train
train_dict = {}
for img in train_images:
  train_dict[img] = img_dict[img]

# %%
# convert a dictionary of clean captions to a list of captions
def to_lines(img_caps):
  all_caps = list() # or []
  for key in img_caps.keys():
    [all_caps.append(cap) for cap in img_caps[key] ]
  return all_caps

# find the maximum length of the
def max_length(img_caps):
  lines = to_lines(img_caps)
  return max(len(line.split()) for line in lines) # split caption by padding then count the word

# determine the maximum sequence length of captions
max_length = max_length(train_dict)
print(f'Captions length: {max_length}')
# Out:
# Captions length: 31

# %%
# load glove model
glove_dir = ''
embeddings_index = {} # empty dictionary
f = open('/content/drive/MyDrive/glove.6B.200d.txt/glove.6B.200d.txt',encoding = 'utf-8')

for line in tqdm(f):
  values = line.split() # 200 dimension and 1 word
  word = values[0]
  coefs = np.asarray(values[1:],dtype = 'float32')
  embeddings_index[word] = coefs 

f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
#   7.6589e-01  6.2383e-01  5.2695e-01  5.5622e-01 -7.1670e-02  3.5850e-01
#  -5.9761e-01  1.4845e-01 -9.3695e-02 -4.8003e-01  1.6384e-01  2.0724e-01
#   1.7857e-02 -2.2912e-01 -2.1439e-01  2.9748e-01 -7.7659e-01 -8.4560e-01
#  -3.3909e-01  2.8332e-01  1.1776e-01  1.6187e-01  5.3056e-01  1.0725e-01
#   2.5875e-01 -2.6135e-01 -2.6731e-01  5.6855e-01 -4.0107e-01  5.1542e-01
#  -1.4011e-01 -2.0160e-01]

# %%
embedding_dim = 200
# create embedding matrix
embedding_matrix = np.zeros((vocab_size,embedding_dim)) # (number of vocab,dimensions)
print(f'embedding_matrix: {embedding_matrix.shape}') # padding word will get zero

for word,i in wordtoix.items():
  embedding_vector = embeddings_index.get(word)
  if embedding_vector is not None:
    # words not found in the embedding index will be all zeros
    embedding_matrix[i] = embedding_vector
# Out:
# embedding_matrix: (1610, 200)

# %%
from keras.layers.merge import add
from keras.layers import Input,Dense,LSTM,Dropout,Embedding
from tensorflow.keras.utils import plot_model

# %%
print(f'vocab_size: {vocab_size}')
print(f'embedding_dim: {embedding_dim}\n')

# build model
input1 = Input(shape = (2048,))
fe1 = Dropout(0.5)(input1)
fe2 = Dense(256,activation = 'relu')(fe1)
input2 = Input(shape = (max_length,))
se1 = Embedding(vocab_size,embedding_dim,mask_zero = True)(input2)
se2 = Dropout(0.5)(se1)
se3 = LSTM(256)(se2)
decoder1 = add([fe2,se3])
decoder2 = Dense(256,activation = 'relu')(decoder1)
output = Dense(vocab_size,activation = 'softmax')(decoder2)
model_word = Model(inputs = [input1,input2],outputs = output)
model_word.summary()
# Out:
# vocab_size: 1610
# embedding_dim: 200
#
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 31)]         0           []
#
#  input_2 (InputLayer)           [(None, 2048)]       0           []
#
#  embedding (Embedding)          (None, 31, 200)      322000      ['input_3[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 31, 200)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 256)          524544      ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 256)          467968      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense[0][0]',
#                                                                   'lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_2 (Dense)                (None, 1610)         413770      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,794,074
# Trainable params: 1,794,074
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_word,
           to_file='model_word.png',
           show_shapes=True,
           show_dtype=True,
           show_layer_names=True
           )

# %%
print(f'embedding_matrix: {embedding_matrix.shape}')
embedding_weight = model_word.layers[2].get_weights()
print(f'embedding_weight: {embedding_weight[0].shape}') # list array
# embedding layer use GLOVE Model weight and we don't need to train
model_word.layers[2].set_weights([embedding_matrix])
model_word.layers[2].trainable = False
# summary your model again
model_word.summary()
# Out:
# embedding_matrix: (1610, 200)
# embedding_weight: (1610, 200)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 31)]         0           []
#
#  input_2 (InputLayer)           [(None, 2048)]       0           []
#
#  embedding (Embedding)          (None, 31, 200)      322000      ['input_3[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 31, 200)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 256)          524544      ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 256)          467968      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense[0][0]',
#                                                                   'lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_2 (Dense)                (None, 1610)         413770      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,794,074
# Trainable params: 1,472,074
# Non-trainable params: 322,000
# __________________________________________________________________________________________________

# %%
model_word.compile(loss = 'categorical_crossentropy',optimizer = 'adam')

# %%
# hyperparameter
model_word.optimizer.lr = 1e-4
epochs = 10
number_pics_per_batch = 6
steps = len(train_dict)//number_pics_per_batch
print(f'learning_rate: {1e-4}')
print(f'epochs: {epochs}')
print(f'number_pics_per_batch: {number_pics_per_batch}')
print(f'steps: {steps}')
print(f'max_length: {max_length}')
print(f'vocab_size: {vocab_size}')
# Out:
# learning_rate: 0.0001
# epochs: 10
# number_pics_per_batch: 6
# steps: 1000
# max_length: 31
# vocab_size: 1610

# %%
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
train_features[img].shape
# Out:
# (2048,)

# %%
# data generator for batch train model.fit_generator()
def data_generator(train_dict,train_features,wordtoix,max_length,number_pics_per_batch):
  X1,X2,y = list(),list(),list()
  n = 0 # iteration each batch size
  # loop over each image
  while 1:
    for img,cap_list in train_dict.items():
      n+=1
      feature_vector = train_features[img]
      for cap in cap_list:
        # encode the sequence
        encoded_cap = [wordtoix[word] for word in cap.split(' ') if word in wordtoix]
        # split one sequence into multiple X,y,pairs
        for i in range(1,len(encoded_cap)): # take the first word start_seq 
          # split into input and output pair
          in_seq,out_seq = encoded_cap[:i],encoded_cap[i] # use the previous word to predict the next word
          # pad input sequence
          in_seq = pad_sequences([in_seq],maxlen = max_length)[0] # [0,0,...,1,2] #(31,)
          # encode output sequence
          out_seq = to_categorical([out_seq],num_classes = vocab_size)[0] # (1610,)
          # store
          X1.append(feature_vector)
          X2.append(in_seq) #(5,31)
          y.append(out_seq) #
        # if you get enough for a batch = 6
      if n == number_pics_per_batch:
        X1,X2,y = np.array(X1),np.array(X2),np.array(y)
        yield [X1,X2],y
        # clear your list
        X1,X2,y = list(),list(),list()
        # reset iteration value
        n=0

# %%
# train the model
for i in range(epochs):
  generator = data_generator(train_dict, train_features, wordtoix, max_length, number_pics_per_batch)
  model_word.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# 1000/1000 [==============================] - 115s 108ms/step - loss: 5.1461
# 1000/1000 [==============================] - 103s 103ms/step - loss: 4.4204
# 1000/1000 [==============================] - 103s 103ms/step - loss: 4.0735
# 1000/1000 [==============================] - 139s 139ms/step - loss: 3.8802
# 1000/1000 [==============================] - 150s 150ms/step - loss: 3.7471
# 1000/1000 [==============================] - 142s 142ms/step - loss: 3.6473
# 1000/1000 [==============================] - 179s 179ms/step - loss: 3.5657
# 1000/1000 [==============================] - 154s 154ms/step - loss: 3.4948
# 1000/1000 [==============================] - 140s 140ms/step - loss: 3.4350
# 1000/1000 [==============================] - 104s 104ms/step - loss: 3.3849

# %%
# save your model weights
model_word.save_weights('./model_flickr8k.h5')

# %%
# store in your drive
# !cp /content/model_flickr8k.h5 /content/drive/MyDrive

# %%
# save full model
model_word.save('model_flickr8k')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_flickr8k/assets
# INFO:tensorflow:Assets written to: model_flickr8k/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd00a679390> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# zip it 
# !zip -r model_flickr8k.zip model_flickr8k
# Out:
#   adding: model_flickr8k/ (stored 0%)
#   adding: model_flickr8k/keras_metadata.pb (deflated 90%)
#   adding: model_flickr8k/variables/ (stored 0%)
#   adding: model_flickr8k/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: model_flickr8k/variables/variables.index (deflated 64%)
#   adding: model_flickr8k/assets/ (stored 0%)
#   adding: model_flickr8k/saved_model.pb (deflated 90%)

# %%
# !cp model_flickr8k.zip /content/drive/MyDrive

# %%
model_word.input_shape
# Out:
# [(None, 2048), (None, 31)]

# %%
# with a image, the input string start with 'startseq' and then put it into model and predict the next word,
# then we add that word into input string, loop over we see 'endseq' or reach max sentences lenght
def greedySearch(feature_vector,verbose = 0):
  in_text ='startseq'
  for i in range(max_length):
    sequence = [wordtoix[word] for word in in_text.split() if word in wordtoix]
    sequence = pad_sequences([sequence],maxlen = max_length)
    yhat = model_word.predict([feature_vector,sequence],verbose = verbose) # [(1,2048),(1,31)]
    yhat = np.argmax(yhat) # (1610,)
    word = ixtoword[yhat] 
    in_text += ' ' + word
    if word == 'endseq':
      break
    final = in_text.split()
    final = final[1:-1] # list
    final = ' '.join(final) # convert list to string
  return final

# test greedySearch
img = random.choice(test_images) 
feature_vector = test_features[img].reshape((1,2048))
print(f'feature_vector: {feature_vector.shape}')
final = greedySearch(feature_vector,1)
final
# Out:
# feature_vector: (1, 2048)
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 'man in blue shirt is sitting on the'

# %%
# random predict with test set
img = random.choice(test_images) 
feature_vector = test_features[img].reshape((1,2048))
x = plt.imread('/content/drive/MyDrive/Flickr8k/Images/' + img)
plt.imshow(x)
plt.title(greedySearch(feature_vector,0))
plt.show()

# %%
# random predict with test set
img = random.choice(valid_images) 
feature_vector = valid_features[img].reshape((1,2048))
x = plt.imread('/content/drive/MyDrive/Flickr8k/Images/' + img)
plt.imshow(x)
plt.title(greedySearch(feature_vector,0))
plt.show()

# %% [markdown]
# ### predict new value

# %%
img = '/content/drive/MyDrive/20220620_181421 (2).jpg'

# image embedding with feature_extractor
feature_vector = encode(img,feature_extractor) # (2048,)
feature_vector = feature_vector.reshape(1,2048)
x = plt.imread(img)
plt.imshow(x)
plt.title(greedySearch(feature_vector,0))
plt.show()

# %% [markdown]
# ### references
#
# [nntuan8](https://github.com/Locchuong96/Machine-Learning/blob/main/Courses/DL_Tutorial/L15/Automatic%20Image%20Captioning.ipynb)
#
# [image caption](https://github.com/divyanshj16/Image-Captioning)
#
# [image-caption-using-tensor-flow](https://www.kaggle.com/code/priyankasharma251997/image-caption-using-tensor-flow)
#
# [bow-vs-skip-gram](https://www.baeldung.com/cs/word-embeddings-cbow-vs-skip-gram)
#
# [word-embedding](https://lilianweng.github.io/posts/2017-10-15-word-embedding/)
